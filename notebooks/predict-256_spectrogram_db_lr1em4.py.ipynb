# %%
import os
import sys
os.chdir('/home/ubuntu/speech2speech')
sys.path.append(os.path.abspath(os.path.dirname('/home/ubuntu/speech2speech') + '/..'))

import matplotlib.pyplot as plt
import math
import pandas as pd
from torchviz import make_dot, make_dot_from_trace
import random
from torchsummary import summary
from torchvision.utils import make_grid
import torchvision.transforms as transforms
import torchvision.datasets as datasets
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset
import torch.nn.functional as F
import torch.nn as nn
import torch
import umap
from six.moves import xrange
from scipy.signal import savgol_filter
import pathlib
import librosa.display
import librosa
import numpy as np
import json
import argparse
from tqdm import tqdm

from speech2speech.data_preprocessing.load_data import *
from speech2speech.models.model import Model
from speech2speech.models.training_utils import *
from torchsummary import summary

# %%
# !ls
# Out:
# FAILED001.test_num_embeddings300_spectrogram_db_lr1em3
# README.md
# __init__.py
# checkpoints
# data
# notebooks
# output
# plots
# scripts
# speech2speech
# test_num_embeddings256_spectrogram_db_lr1em4
# test_num_embeddings300_spectrogram_db_lr1em3
# test_num_embeddings300_spectrogram_db_lr1em4
# test_num_embeddings_500

# %%
device = torch.device("cuda")

# %%
checkpoint_dir = os.path.join('/home/ubuntu/speech2speech/test_num_embeddings256_spectrogram_db_lr1em4/', 'checkpoints')

# %%
def get_latest_checkpoint(checkpoint_dir):
    '''
Return the latest checkpoint index and file in user provided directory
    '''
    all_files = {}
    file_list = glob.glob(os.path.join(checkpoint_dir, 'checkpoint*'))
    latest_file = max(file_list, key=os.path.getctime)
    
    return latest_file

# %%
get_latest_checkpoint(checkpoint_dir)
# Out:
# '/home/ubuntu/speech2speech/test_num_embeddings256_spectrogram_db_lr1em4/checkpoints/checkpoint_state_dict_20'

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
spectrogram_dir= '/home/ubuntu/speech2speech/data/interim/spectogram_array_path_trim_30db_ntft_512'

# %%
num_hiddens = 768
num_residual_layers = 2
num_residual_hiddens = 32
num_embeddings = 256
embedding_dim = 64
commitment_cost = 0.25
files_np = list(glob.glob(os.path.join(spectrogram_dir, '*.*')))
speaker_dic = speaker_id_dic(files_np)
speaker_id = '260'
speaker_embedding_dim = 20
decay = 0
learning_rate = 1e-4
batch_size  = 10
time_length = 100
num_epochs = 20

# %%
model = Model(num_hiddens, num_residual_layers, num_residual_hiddens,
              num_embeddings, embedding_dim,
              commitment_cost, speaker_dic, speaker_id, speaker_embedding_dim, decay, device).to(device)

# %%
optimizer = optim.Adam(model.parameters(), lr=learning_rate, amsgrad=False)

# %%
def load_checkpoint(model, optimizer, filename):
    # Note: Input model & optimizer should be pre-defined.  This routine only updates their states.
    start_epoch = 0
    if os.path.isfile(filename):
        print("=> loading checkpoint '{}'".format(filename))
        checkpoint = torch.load(filename)
        start_epoch = checkpoint['epoch']
        model.load_state_dict(checkpoint['state_dict'])
        optimizer.load_state_dict(checkpoint['optimizer'])
        print("=> loaded checkpoint '{}' (epoch {})"
                  .format(filename, checkpoint['epoch']))
    else:
        print("=> no checkpoint found at '{}'".format(filename))

    return model, optimizer, start_epoch

# %%
tensordataset = spectrograms_to_torch_dataset(files_np, time_length)

# %%
train_dataset, val_dataset, test_dataset = split_dataset(
    tensordataset, 0.8, 0.1)

# %%
training_loader, validation_loader = train_val_data_loaders(train_dataset, val_dataset, batch_size)

# %%
load_checkpoint(model, optimizer, get_latest_checkpoint(checkpoint_dir))
# Out:
# => loading checkpoint '/home/ubuntu/speech2speech/test_num_embeddings256_spectrogram_db_lr1em4/checkpoints/checkpoint_state_dict_20'
# => loaded checkpoint '/home/ubuntu/speech2speech/test_num_embeddings256_spectrogram_db_lr1em4/checkpoints/checkpoint_state_dict_20' (epoch 20)
# (Model(
#    (_encoder): Encoder(
#      (_conv_1): Conv1d(257, 768, kernel_size=(3,), stride=(1,), padding=(1,))
#      (_conv_2): Conv1d(768, 768, kernel_size=(3,), stride=(1,), padding=(1,))
#      (_conv_3): Conv1d(768, 768, kernel_size=(4,), stride=(1,), padding=(2,))
#      (_conv_4): Conv1d(768, 768, kernel_size=(3,), stride=(1,), padding=(1,))
#      (_conv_5): Conv1d(768, 768, kernel_size=(3,), stride=(1,), padding=(1,))
#      (_residual_stack): ResidualStack(
#        (_layers): ModuleList(
#          (0): Residual(
#            (_block): Sequential(
#              (0): ReLU(inplace=True)
#              (1): Conv1d(768, 32, kernel_size=(3,), stride=(1,), padding=(1,), bias=False)
#              (2): ReLU(inplace=True)
#              (3): Conv1d(32, 768, kernel_size=(1,), stride=(1,), bias=False)
#            )
#          )
#          (1): Residual(
#            (_block): Sequential(
#              (0): ReLU(inplace=True)
#              (1): Conv1d(768, 32, kernel_size=(3,), stride=(1,), padding=(1,), bias=False)
#              (2): ReLU(inplace=True)
#              (3): Conv1d(32, 768, kernel_size=(1,), stride=(1,), bias=False)
#            )
#          )
#        )
#      )
#    )
#    (_pre_vq_conv): Conv1d(768, 64, kernel_size=(1,), stride=(1,))
#    (_vq_vae): VectorQuantizer(
#      (_embedding): Embedding(256, 64)
#    )
#    (_decoder): Decoder(
#      (_embedding): Embedding(109, 20)
#      (_conv_1): Conv1d(84, 768, kernel_size=(3,), stride=(1,), padding=(1,))
#      (_upsample): Upsample(scale_factor=2.0, mode=nearest)
#      (_residual_stack): ResidualStack(
#        (_layers): ModuleList(
#          (0): Residual(
#            (_block): Sequential(
#              (0): ReLU(inplace=True)
#              (1): Conv1d(768, 32, kernel_size=(3,), stride=(1,), padding=(1,), bias=False)
#              (2): ReLU(inplace=True)
#              (3): Conv1d(32, 768, kernel_size=(1,), stride=(1,), bias=False)
#            )
#          )
#          (1): Residual(
#            (_block): Sequential(
#              (0): ReLU(inplace=True)
#              (1): Conv1d(768, 32, kernel_size=(3,), stride=(1,), padding=(1,), bias=False)
#              (2): ReLU(inplace=True)
#              (3): Conv1d(32, 768, kernel_size=(1,), stride=(1,), bias=False)
#            )
#          )
#        )
#      )
#      (_conv_trans_1): ConvTranspose1d(768, 768, kernel_size=(3,), stride=(1,), padding=(1,))
#      (_conv_trans_2): ConvTranspose1d(768, 768, kernel_size=(3,), stride=(1,))
#      (_conv_trans_3): ConvTranspose1d(768, 257, kernel_size=(3,), stride=(1,), padding=(3,))
#    )
#  ), Adam (
#  Parameter Group 0
#      amsgrad: False
#      betas: (0.9, 0.999)
#      eps: 1e-08
#      lr: 0.0001
#      weight_decay: 0
#  ), 20)

# %%
(data, _) = next(iter(training_loader))
data = data.to(device)

vq_loss, data_recon, perplexity = model(data)

# %%
for i in range(len(data)):
    data_np = (data[i].to(torch.device("cpu"))).detach().numpy();
    data_np = librosa.db_to_amplitude(data_np)
    data_griffin_lim = librosa.griffinlim(data_np)
    data_recon_np = (data_recon[i].to(torch.device("cpu"))).detach().numpy();
    data_recon_np = librosa.db_to_amplitude(data_recon_np)
    data_recon_griffin_lim = librosa.griffinlim(data_recon_np)
    
    fig = plt.figure(figsize=(16, 8))
    ax = plt.subplot(2,1,1)
    output_path = '/home/ubuntu/speech2speech/test_num_embeddings256_spectrogram_db_lr1em4/plots/raw_plot_' + str(i) + '.png'
    source_aud_path = '/home/ubuntu/speech2speech/test_num_embeddings256_spectrogram_db_lr1em4/output/source_' + str(i) + '.wav'
    target_aud_path =  '/home/ubuntu/speech2speech/test_num_embeddings256_spectrogram_db_lr1em4/output/target_' + str(i) + '.wav'
    
    librosa.display.waveplot(data_griffin_lim, color = 'g')
    plt.title('Source Audio')
    plt.xlabel('')
    plt.subplot(2,1,2, sharex=ax, sharey=ax)
    plt.title('Target Audio')
    librosa.display.waveplot(data_recon_griffin_lim, color = 'b')
    plt.tight_layout()
    fig.savefig(output_path)
    
    librosa.output.write_wav(source_aud_path,data_griffin_lim, 16384)
    librosa.output.write_wav(target_aud_path,data_recon_griffin_lim, 16384)

# %%
for i in range(len(data)):
    data_np = (data[i].to(torch.device("cpu"))).detach().numpy();
    data_np = librosa.db_to_amplitude(data_np)
    data_griffin_lim = librosa.griffinlim(data_np)
    data_recon_np = (data_recon[i].to(torch.device("cpu"))).detach().numpy();
    data_recon_np = librosa.db_to_amplitude(data_recon_np)
    data_recon_griffin_lim = librosa.griffinlim(data_recon_np)
    
    fig = plt.figure(figsize=(16, 8))
    ax = plt.subplot(2,1,1)
    output_path = '/home/ubuntu/speech2speech/test_num_embeddings256_spectrogram_db_lr1em4/plots/spec_plot_' + str(i) + '.png'

    librosa.display.specshow(data_np, sr=16384, x_axis='time', y_axis='log')
    plt.title('Source Audio')
    plt.xlabel('')
    plt.colorbar()
    plt.subplot(2,1,2, sharex=ax, sharey=ax)
    plt.title('Target Audio')
    librosa.display.specshow(40*data_recon_np, sr=16384, x_axis='time', y_axis='log')
    plt.colorbar()
    plt.tight_layout()
    fig.savefig(output_path)

# %%
np.any(data[7].to(torch.device("cpu")).numpy() < 0 )
# Out:
# False

# %%
model.eval() # enter evaluation mode
val_res_recon_error = []
train_res_perplexity = []
epoch_loss = 0
with torch.no_grad():
    for epoch in range(num_epochs):
        std, _ = std_mean_dataloader(validation_loader)
        for i, (x, _) in enumerate(validation_loader):
            batch_X = x.to(device)
            # forward pass
            vq_loss, data_recon, perplexity = model(batch_X)
            recon_error = F.mse_loss(data_recon, x.cuda()) / std
            loss = recon_error + vq_loss
            epoch_loss += loss.item()

            if (i+1) % 10 == 0:
                print ("Epoch[{}/{}], Step [{}/{}], recon_error: {:.4f}, perplexity: {:.4f}"
                   .format(epoch+1, num_epochs, i+1, len(training_loader), recon_error.item(), perplexity.item()))
                
        val_res_recon_error.append(recon_error.item())
        train_res_perplexity.append(perplexity.item())
        epoch_loss
# Out:
# Epoch[1/20], Step [10/3540], recon_error: 1.0074, perplexity: 11.1514
# Epoch[1/20], Step [20/3540], recon_error: 0.7826, perplexity: 8.2006
# Epoch[1/20], Step [30/3540], recon_error: 0.8856, perplexity: 9.9572
# Epoch[1/20], Step [40/3540], recon_error: 1.2405, perplexity: 10.7006
# Epoch[1/20], Step [50/3540], recon_error: 1.5537, perplexity: 12.6538
# Epoch[1/20], Step [60/3540], recon_error: 0.7761, perplexity: 10.9095
# Epoch[1/20], Step [70/3540], recon_error: 0.9391, perplexity: 11.9851
# Epoch[1/20], Step [80/3540], recon_error: 0.9424, perplexity: 10.9733
# Epoch[1/20], Step [90/3540], recon_error: 1.4172, perplexity: 14.9323
# Epoch[1/20], Step [100/3540], recon_error: 1.2381, perplexity: 12.9405
# Epoch[1/20], Step [110/3540], recon_error: 1.1825, perplexity: 11.6221
# Epoch[1/20], Step [120/3540], recon_error: 1.2339, perplexity: 13.6039
# Epoch[1/20], Step [130/3540], recon_error: 1.0449, perplexity: 10.7599
# Epoch[1/20], Step [140/3540], recon_error: 1.0384, perplexity: 10.0622
# Epoch[1/20], Step [150/3540], recon_error: 1.3467, perplexity: 15.3759
# Epoch[1/20], Step [160/3540], recon_error: 1.0479, perplexity: 11.9793
# Epoch[1/20], Step [170/3540], recon_error: 0.8171, perplexity: 11.2505
# Epoch[1/20], Step [180/3540], recon_error: 1.4143, perplexity: 14.3569
# Epoch[1/20], Step [190/3540], recon_error: 0.8413, perplexity: 8.0453
# Epoch[1/20], Step [200/3540], recon_error: 0.9976, perplexity: 10.7912
# Epoch[1/20], Step [210/3540], recon_error: 0.9096, perplexity: 10.8135
# Epoch[1/20], Step [220/3540], recon_error: 0.9458, perplexity: 13.2773
# Epoch[1/20], Step [230/3540], recon_error: 0.7958, perplexity: 8.7968
# Epoch[1/20], Step [240/3540], recon_error: 1.3779, perplexity: 12.9778
# Epoch[1/20], Step [250/3540], recon_error: 1.2925, perplexity: 14.8981
# Epoch[1/20], Step [260/3540], recon_error: 1.1845, perplexity: 10.6996
# Epoch[1/20], Step [270/3540], recon_error: 1.2335, perplexity: 13.5564
# Epoch[1/20], Step [280/3540], recon_error: 1.4411, perplexity: 13.2000
# Epoch[1/20], Step [290/3540], recon_error: 0.6881, perplexity: 8.4923
# Epoch[1/20], Step [300/3540], recon_error: 1.7777, perplexity: 12.4922
# Epoch[1/20], Step [310/3540], recon_error: 0.9603, perplexity: 10.6356
# Epoch[1/20], Step [320/3540], recon_error: 0.5527, perplexity: 7.2782
# Epoch[1/20], Step [330/3540], recon_error: 1.0825, perplexity: 9.9949
# Epoch[1/20], Step [340/3540], recon_error: 0.8301, perplexity: 8.7136
# Epoch[1/20], Step [350/3540], recon_error: 1.6594, perplexity: 18.9158
# Epoch[1/20], Step [360/3540], recon_error: 2.0136, perplexity: 15.5915
# Epoch[1/20], Step [370/3540], recon_error: 1.3600, perplexity: 12.8400
# Epoch[1/20], Step [380/3540], recon_error: 0.9079, perplexity: 8.9231
# Epoch[1/20], Step [390/3540], recon_error: 1.1157, perplexity: 9.6155
# Epoch[1/20], Step [400/3540], recon_error: 0.9732, perplexity: 9.7815
# Epoch[1/20], Step [410/3540], recon_error: 1.1663, perplexity: 13.3136
# Epoch[1/20], Step [420/3540], recon_error: 0.8418, perplexity: 8.8224
# Epoch[1/20], Step [430/3540], recon_error: 0.9942, perplexity: 13.5048
# Epoch[1/20], Step [440/3540], recon_error: 1.2985, perplexity: 10.5046
# Epoch[2/20], Step [10/3540], recon_error: 1.2182, perplexity: 14.4637
# Epoch[2/20], Step [20/3540], recon_error: 1.3530, perplexity: 14.6218
# Epoch[2/20], Step [30/3540], recon_error: 1.6964, perplexity: 15.3781
# Epoch[2/20], Step [40/3540], recon_error: 1.6870, perplexity: 15.5367
# Epoch[2/20], Step [50/3540], recon_error: 1.2050, perplexity: 12.8189
# Epoch[2/20], Step [60/3540], recon_error: 1.4214, perplexity: 14.2904
# Epoch[2/20], Step [70/3540], recon_error: 0.9779, perplexity: 8.9631
# Epoch[2/20], Step [80/3540], recon_error: 1.0911, perplexity: 11.9530
# Epoch[2/20], Step [90/3540], recon_error: 0.9780, perplexity: 10.1562
# Epoch[2/20], Step [100/3540], recon_error: 1.1321, perplexity: 10.0252
# Epoch[2/20], Step [110/3540], recon_error: 1.1854, perplexity: 14.4712
# Epoch[2/20], Step [120/3540], recon_error: 0.8829, perplexity: 11.0979
# Epoch[2/20], Step [130/3540], recon_error: 1.4474, perplexity: 13.5578
# Epoch[2/20], Step [140/3540], recon_error: 0.6306, perplexity: 7.2727
# Epoch[2/20], Step [150/3540], recon_error: 0.6818, perplexity: 8.1285
# Epoch[2/20], Step [160/3540], recon_error: 0.9858, perplexity: 9.0587
# Epoch[2/20], Step [170/3540], recon_error: 0.7947, perplexity: 10.3341
# Epoch[2/20], Step [180/3540], recon_error: 1.2386, perplexity: 10.3925
# Epoch[2/20], Step [190/3540], recon_error: 0.6547, perplexity: 6.6115
# Epoch[2/20], Step [200/3540], recon_error: 0.8071, perplexity: 9.1873
# Epoch[2/20], Step [210/3540], recon_error: 0.7716, perplexity: 7.2329
# Epoch[2/20], Step [220/3540], recon_error: 0.9853, perplexity: 11.0395
# Epoch[2/20], Step [230/3540], recon_error: 1.7896, perplexity: 16.9227
# Epoch[2/20], Step [240/3540], recon_error: 1.2053, perplexity: 14.5953
# Epoch[2/20], Step [250/3540], recon_error: 0.7923, perplexity: 11.2200
# Epoch[2/20], Step [260/3540], recon_error: 1.5773, perplexity: 15.8113
# Epoch[2/20], Step [270/3540], recon_error: 1.7187, perplexity: 14.4371
# Epoch[2/20], Step [280/3540], recon_error: 0.8069, perplexity: 10.8389
# Epoch[2/20], Step [290/3540], recon_error: 1.9287, perplexity: 22.3313
# Epoch[2/20], Step [300/3540], recon_error: 0.7863, perplexity: 10.5201
# Epoch[2/20], Step [310/3540], recon_error: 0.7838, perplexity: 8.0898
# Epoch[2/20], Step [320/3540], recon_error: 1.1106, perplexity: 12.0401
# Epoch[2/20], Step [330/3540], recon_error: 1.0899, perplexity: 10.4319
# Epoch[2/20], Step [340/3540], recon_error: 1.0848, perplexity: 12.6341
# Epoch[2/20], Step [350/3540], recon_error: 0.7391, perplexity: 11.2149
# Epoch[2/20], Step [360/3540], recon_error: 1.6955, perplexity: 18.4722
# Epoch[2/20], Step [370/3540], recon_error: 0.7750, perplexity: 8.9882
# Epoch[2/20], Step [380/3540], recon_error: 1.6319, perplexity: 16.0372
# Epoch[2/20], Step [390/3540], recon_error: 0.9459, perplexity: 11.1550
# Epoch[2/20], Step [400/3540], recon_error: 1.2675, perplexity: 15.2348
# Epoch[2/20], Step [410/3540], recon_error: 1.9165, perplexity: 16.6801
# Epoch[2/20], Step [420/3540], recon_error: 1.8395, perplexity: 14.4425
# Epoch[2/20], Step [430/3540], recon_error: 0.9114, perplexity: 10.5068
# Epoch[2/20], Step [440/3540], recon_error: 1.4721, perplexity: 15.2573
# Epoch[3/20], Step [10/3540], recon_error: 1.4021, perplexity: 11.0844
# Epoch[3/20], Step [20/3540], recon_error: 1.3524, perplexity: 11.4389
# Epoch[3/20], Step [30/3540], recon_error: 1.3170, perplexity: 11.6174
# Epoch[3/20], Step [40/3540], recon_error: 1.6833, perplexity: 15.8447
# Epoch[3/20], Step [50/3540], recon_error: 1.0384, perplexity: 10.9412
# Epoch[3/20], Step [60/3540], recon_error: 1.5992, perplexity: 10.8345
# Epoch[3/20], Step [70/3540], recon_error: 1.8475, perplexity: 15.9327
# Epoch[3/20], Step [80/3540], recon_error: 1.9543, perplexity: 16.1532
# Epoch[3/20], Step [90/3540], recon_error: 1.7920, perplexity: 14.5670
# Epoch[3/20], Step [100/3540], recon_error: 1.9041, perplexity: 14.1898
# Epoch[3/20], Step [110/3540], recon_error: 2.3253, perplexity: 13.6433
# Epoch[3/20], Step [120/3540], recon_error: 1.8679, perplexity: 17.9348
# Epoch[3/20], Step [130/3540], recon_error: 1.7470, perplexity: 13.3136
# Epoch[3/20], Step [140/3540], recon_error: 1.5319, perplexity: 12.2405
# Epoch[3/20], Step [150/3540], recon_error: 1.3362, perplexity: 10.5510
# Epoch[3/20], Step [160/3540], recon_error: 1.1657, perplexity: 10.7995
# Epoch[3/20], Step [170/3540], recon_error: 0.8356, perplexity: 9.0425
# Epoch[3/20], Step [180/3540], recon_error: 1.6345, perplexity: 17.1129
# Epoch[3/20], Step [190/3540], recon_error: 1.4729, perplexity: 12.9196
# Epoch[3/20], Step [200/3540], recon_error: 1.2489, perplexity: 9.4551
# Epoch[3/20], Step [210/3540], recon_error: 1.7189, perplexity: 15.6410
# Epoch[3/20], Step [220/3540], recon_error: 1.3135, perplexity: 11.0463
# Epoch[3/20], Step [230/3540], recon_error: 1.7220, perplexity: 15.9937
# Epoch[3/20], Step [240/3540], recon_error: 1.4055, perplexity: 13.5692
# Epoch[3/20], Step [250/3540], recon_error: 0.9840, perplexity: 11.5837
# Epoch[3/20], Step [260/3540], recon_error: 1.9041, perplexity: 14.7732
# Epoch[3/20], Step [270/3540], recon_error: 1.2861, perplexity: 13.4982
# Epoch[3/20], Step [280/3540], recon_error: 1.7596, perplexity: 14.8023
# Epoch[3/20], Step [290/3540], recon_error: 1.5693, perplexity: 11.9869
# Epoch[3/20], Step [300/3540], recon_error: 1.0436, perplexity: 8.6656
# Epoch[3/20], Step [310/3540], recon_error: 0.9354, perplexity: 7.8121
# Epoch[3/20], Step [320/3540], recon_error: 1.2266, perplexity: 14.5931
# Epoch[3/20], Step [330/3540], recon_error: 0.9687, perplexity: 10.3562
# Epoch[3/20], Step [340/3540], recon_error: 1.2561, perplexity: 11.6979
# Epoch[3/20], Step [350/3540], recon_error: 1.1229, perplexity: 9.9681
# Epoch[3/20], Step [360/3540], recon_error: 1.5171, perplexity: 12.8567
# Epoch[3/20], Step [370/3540], recon_error: 1.2291, perplexity: 10.8598
# Epoch[3/20], Step [380/3540], recon_error: 0.7588, perplexity: 9.1148
# Epoch[3/20], Step [390/3540], recon_error: 1.2003, perplexity: 13.5682
# Epoch[3/20], Step [400/3540], recon_error: 1.2946, perplexity: 10.7736
# Epoch[3/20], Step [410/3540], recon_error: 1.8538, perplexity: 15.5671
# Epoch[3/20], Step [420/3540], recon_error: 1.8751, perplexity: 12.1972
# Epoch[3/20], Step [430/3540], recon_error: 0.8899, perplexity: 8.6812
# Epoch[3/20], Step [440/3540], recon_error: 1.5747, perplexity: 13.6064
# Epoch[4/20], Step [10/3540], recon_error: 0.9133, perplexity: 13.2971
# Epoch[4/20], Step [20/3540], recon_error: 0.6486, perplexity: 10.1427
# Epoch[4/20], Step [30/3540], recon_error: 0.6116, perplexity: 7.9680
# Epoch[4/20], Step [40/3540], recon_error: 0.9582, perplexity: 13.7794
# Epoch[4/20], Step [50/3540], recon_error: 0.6996, perplexity: 9.3814
# Epoch[4/20], Step [60/3540], recon_error: 1.0524, perplexity: 17.0053
# Epoch[4/20], Step [70/3540], recon_error: 0.6801, perplexity: 8.2097
# Epoch[4/20], Step [80/3540], recon_error: 1.0443, perplexity: 16.0174
# Epoch[4/20], Step [90/3540], recon_error: 0.9048, perplexity: 10.0971
# Epoch[4/20], Step [100/3540], recon_error: 0.8362, perplexity: 11.5477
# Epoch[4/20], Step [110/3540], recon_error: 0.8608, perplexity: 11.5821
# Epoch[4/20], Step [120/3540], recon_error: 0.7863, perplexity: 10.7221
# Epoch[4/20], Step [130/3540], recon_error: 0.7729, perplexity: 11.5426
# Epoch[4/20], Step [140/3540], recon_error: 0.5434, perplexity: 7.8291
# Epoch[4/20], Step [150/3540], recon_error: 1.1092, perplexity: 10.9318
# Epoch[4/20], Step [160/3540], recon_error: 0.8698, perplexity: 10.3632
# Epoch[4/20], Step [170/3540], recon_error: 1.1472, perplexity: 15.5158
# Epoch[4/20], Step [180/3540], recon_error: 0.8937, perplexity: 11.1442
# Epoch[4/20], Step [190/3540], recon_error: 0.8432, perplexity: 14.3347
# Epoch[4/20], Step [200/3540], recon_error: 0.8534, perplexity: 11.8737
# Epoch[4/20], Step [210/3540], recon_error: 0.7671, perplexity: 11.8735
# Epoch[4/20], Step [220/3540], recon_error: 0.8782, perplexity: 12.5065
# Epoch[4/20], Step [230/3540], recon_error: 0.9702, perplexity: 10.1145
# Epoch[4/20], Step [240/3540], recon_error: 0.7967, perplexity: 12.4528
# Epoch[4/20], Step [250/3540], recon_error: 0.8068, perplexity: 10.4942
# Epoch[4/20], Step [260/3540], recon_error: 0.8646, perplexity: 10.3370
# Epoch[4/20], Step [270/3540], recon_error: 0.6819, perplexity: 10.1587
# Epoch[4/20], Step [280/3540], recon_error: 1.2139, perplexity: 20.7774
# Epoch[4/20], Step [290/3540], recon_error: 0.9901, perplexity: 13.6345
# Epoch[4/20], Step [300/3540], recon_error: 0.7788, perplexity: 9.6863
# Epoch[4/20], Step [310/3540], recon_error: 1.0017, perplexity: 10.9938
# Epoch[4/20], Step [320/3540], recon_error: 0.9876, perplexity: 13.8532
# Epoch[4/20], Step [330/3540], recon_error: 0.6748, perplexity: 10.9532
# Epoch[4/20], Step [340/3540], recon_error: 0.8866, perplexity: 11.0310
# Epoch[4/20], Step [350/3540], recon_error: 0.6138, perplexity: 10.7727
# Epoch[4/20], Step [360/3540], recon_error: 0.9557, perplexity: 13.3838
# Epoch[4/20], Step [370/3540], recon_error: 1.0611, perplexity: 9.3523
# Epoch[4/20], Step [380/3540], recon_error: 0.8308, perplexity: 13.6026
# Epoch[4/20], Step [390/3540], recon_error: 0.9337, perplexity: 11.7660
# Epoch[4/20], Step [400/3540], recon_error: 0.5966, perplexity: 8.9124
# Epoch[4/20], Step [410/3540], recon_error: 0.7726, perplexity: 10.5260
# Epoch[4/20], Step [420/3540], recon_error: 0.7214, perplexity: 11.8957
# Epoch[4/20], Step [430/3540], recon_error: 1.0167, perplexity: 17.3667
# Epoch[4/20], Step [440/3540], recon_error: 1.9012, perplexity: 18.7849
# Epoch[5/20], Step [10/3540], recon_error: 0.9640, perplexity: 14.7553
# Epoch[5/20], Step [20/3540], recon_error: 1.1187, perplexity: 12.0884
# Epoch[5/20], Step [30/3540], recon_error: 0.6008, perplexity: 8.9942
# Epoch[5/20], Step [40/3540], recon_error: 0.7700, perplexity: 9.4531
# Epoch[5/20], Step [50/3540], recon_error: 0.7009, perplexity: 11.6340
# Epoch[5/20], Step [60/3540], recon_error: 0.9969, perplexity: 13.1166
# Epoch[5/20], Step [70/3540], recon_error: 0.8008, perplexity: 9.0971
# Epoch[5/20], Step [80/3540], recon_error: 0.6000, perplexity: 8.5104
# Epoch[5/20], Step [90/3540], recon_error: 0.9759, perplexity: 14.2224
# Epoch[5/20], Step [100/3540], recon_error: 0.8576, perplexity: 12.7359
# Epoch[5/20], Step [110/3540], recon_error: 0.6740, perplexity: 11.5163
# Epoch[5/20], Step [120/3540], recon_error: 1.0600, perplexity: 10.8623
# Epoch[5/20], Step [130/3540], recon_error: 1.1087, perplexity: 14.7456
# Epoch[5/20], Step [140/3540], recon_error: 1.0774, perplexity: 15.9724
# Epoch[5/20], Step [150/3540], recon_error: 1.2270, perplexity: 13.1945
# Epoch[5/20], Step [160/3540], recon_error: 0.7175, perplexity: 11.3889
# Epoch[5/20], Step [170/3540], recon_error: 1.1772, perplexity: 11.0386
# Epoch[5/20], Step [180/3540], recon_error: 0.8939, perplexity: 11.7351
# Epoch[5/20], Step [190/3540], recon_error: 0.8503, perplexity: 10.1800
# Epoch[5/20], Step [200/3540], recon_error: 0.9141, perplexity: 11.6120
# Epoch[5/20], Step [210/3540], recon_error: 1.1551, perplexity: 13.6699
# Epoch[5/20], Step [220/3540], recon_error: 0.9594, perplexity: 11.8135
# Epoch[5/20], Step [230/3540], recon_error: 1.0006, perplexity: 10.2752
# Epoch[5/20], Step [240/3540], recon_error: 1.3176, perplexity: 13.7342
# Epoch[5/20], Step [250/3540], recon_error: 0.5743, perplexity: 8.6579
# Epoch[5/20], Step [260/3540], recon_error: 0.7797, perplexity: 10.8273
# Epoch[5/20], Step [270/3540], recon_error: 1.5551, perplexity: 20.3119
# Epoch[5/20], Step [280/3540], recon_error: 0.6043, perplexity: 8.3196
# Epoch[5/20], Step [290/3540], recon_error: 0.8479, perplexity: 12.3902
# Epoch[5/20], Step [300/3540], recon_error: 0.7651, perplexity: 11.1689
# Epoch[5/20], Step [310/3540], recon_error: 0.8865, perplexity: 12.0169
# Epoch[5/20], Step [320/3540], recon_error: 0.8009, perplexity: 10.6383
# Epoch[5/20], Step [330/3540], recon_error: 0.6283, perplexity: 9.2374
# Epoch[5/20], Step [340/3540], recon_error: 1.2432, perplexity: 10.2998
# Epoch[5/20], Step [350/3540], recon_error: 0.6052, perplexity: 9.9298
# Epoch[5/20], Step [360/3540], recon_error: 1.0385, perplexity: 11.9786
# Epoch[5/20], Step [370/3540], recon_error: 0.4392, perplexity: 7.7983
# Epoch[5/20], Step [380/3540], recon_error: 0.9675, perplexity: 14.3149
# Epoch[5/20], Step [390/3540], recon_error: 0.9385, perplexity: 8.3177
# Epoch[5/20], Step [400/3540], recon_error: 0.7760, perplexity: 10.1595
# Epoch[5/20], Step [410/3540], recon_error: 1.0221, perplexity: 15.0771
# Epoch[5/20], Step [420/3540], recon_error: 1.3412, perplexity: 14.1913
# Epoch[5/20], Step [430/3540], recon_error: 0.7871, perplexity: 9.8388
# Epoch[5/20], Step [440/3540], recon_error: 1.6913, perplexity: 18.1747
# Epoch[6/20], Step [10/3540], recon_error: 1.5851, perplexity: 16.4213
# Epoch[6/20], Step [20/3540], recon_error: 0.9075, perplexity: 8.9560
# Epoch[6/20], Step [30/3540], recon_error: 0.4583, perplexity: 5.2194
# Epoch[6/20], Step [40/3540], recon_error: 0.8151, perplexity: 7.8694
# Epoch[6/20], Step [50/3540], recon_error: 0.7973, perplexity: 8.6635
# Epoch[6/20], Step [60/3540], recon_error: 0.7333, perplexity: 11.5317
# Epoch[6/20], Step [70/3540], recon_error: 1.3820, perplexity: 16.8742
# Epoch[6/20], Step [80/3540], recon_error: 1.0822, perplexity: 13.7173
# Epoch[6/20], Step [90/3540], recon_error: 0.7634, perplexity: 9.6750
# Epoch[6/20], Step [100/3540], recon_error: 0.8088, perplexity: 10.5802
# Epoch[6/20], Step [110/3540], recon_error: 0.9830, perplexity: 13.7569
# Epoch[6/20], Step [120/3540], recon_error: 1.3072, perplexity: 11.1976
# Epoch[6/20], Step [130/3540], recon_error: 1.0366, perplexity: 15.3818
# Epoch[6/20], Step [140/3540], recon_error: 1.0178, perplexity: 9.7368
# Epoch[6/20], Step [150/3540], recon_error: 1.1061, perplexity: 11.3519
# Epoch[6/20], Step [160/3540], recon_error: 1.7499, perplexity: 12.5489
# Epoch[6/20], Step [170/3540], recon_error: 0.5830, perplexity: 9.0405
# Epoch[6/20], Step [180/3540], recon_error: 1.0406, perplexity: 14.0528
# Epoch[6/20], Step [190/3540], recon_error: 0.7007, perplexity: 9.5838
# Epoch[6/20], Step [200/3540], recon_error: 1.1446, perplexity: 13.7666
# Epoch[6/20], Step [210/3540], recon_error: 1.0301, perplexity: 10.0067
# Epoch[6/20], Step [220/3540], recon_error: 1.1531, perplexity: 13.5757
# Epoch[6/20], Step [230/3540], recon_error: 1.3126, perplexity: 14.2747
# Epoch[6/20], Step [240/3540], recon_error: 0.8427, perplexity: 9.0798
# Epoch[6/20], Step [250/3540], recon_error: 1.2208, perplexity: 11.1854
# Epoch[6/20], Step [260/3540], recon_error: 0.8891, perplexity: 11.5413
# Epoch[6/20], Step [270/3540], recon_error: 1.3554, perplexity: 17.9548
# Epoch[6/20], Step [280/3540], recon_error: 0.7461, perplexity: 8.8158
# Epoch[6/20], Step [290/3540], recon_error: 1.0546, perplexity: 13.2515
# Epoch[6/20], Step [300/3540], recon_error: 1.3932, perplexity: 13.8349
# Epoch[6/20], Step [310/3540], recon_error: 0.9894, perplexity: 9.9244
# Epoch[6/20], Step [320/3540], recon_error: 0.7563, perplexity: 9.3412
# Epoch[6/20], Step [330/3540], recon_error: 1.2965, perplexity: 19.4582
# Epoch[6/20], Step [340/3540], recon_error: 1.1949, perplexity: 12.7184
# Epoch[6/20], Step [350/3540], recon_error: 1.1571, perplexity: 15.0795
# Epoch[6/20], Step [360/3540], recon_error: 1.4046, perplexity: 13.6095
# Epoch[6/20], Step [370/3540], recon_error: 0.7166, perplexity: 11.2179
# Epoch[6/20], Step [380/3540], recon_error: 1.1505, perplexity: 12.2348
# Epoch[6/20], Step [390/3540], recon_error: 1.1915, perplexity: 14.6069
# Epoch[6/20], Step [400/3540], recon_error: 0.9983, perplexity: 12.3819
# Epoch[6/20], Step [410/3540], recon_error: 0.8414, perplexity: 14.6291
# Epoch[6/20], Step [420/3540], recon_error: 0.9917, perplexity: 13.4726
# Epoch[6/20], Step [430/3540], recon_error: 1.0257, perplexity: 11.2342
# Epoch[6/20], Step [440/3540], recon_error: 0.8612, perplexity: 9.7858
# Epoch[7/20], Step [10/3540], recon_error: 0.8665, perplexity: 12.3211
# Epoch[7/20], Step [20/3540], recon_error: 1.1038, perplexity: 13.8858
# Epoch[7/20], Step [30/3540], recon_error: 0.9819, perplexity: 13.9684
# Epoch[7/20], Step [40/3540], recon_error: 0.9215, perplexity: 12.4606
# Epoch[7/20], Step [50/3540], recon_error: 0.7660, perplexity: 10.1879
# Epoch[7/20], Step [60/3540], recon_error: 0.9994, perplexity: 13.5885
# Epoch[7/20], Step [70/3540], recon_error: 0.4989, perplexity: 8.5397
# Epoch[7/20], Step [80/3540], recon_error: 0.9923, perplexity: 12.8224
# Epoch[7/20], Step [90/3540], recon_error: 0.6513, perplexity: 10.0253
# Epoch[7/20], Step [100/3540], recon_error: 1.1136, perplexity: 13.3903
# Epoch[7/20], Step [110/3540], recon_error: 0.6587, perplexity: 11.7977
# Epoch[7/20], Step [120/3540], recon_error: 1.5744, perplexity: 18.3434
# Epoch[7/20], Step [130/3540], recon_error: 1.1345, perplexity: 10.0451
# Epoch[7/20], Step [140/3540], recon_error: 0.8051, perplexity: 12.2476
# Epoch[7/20], Step [150/3540], recon_error: 1.0995, perplexity: 13.6053
# Epoch[7/20], Step [160/3540], recon_error: 0.7726, perplexity: 10.7031
# Epoch[7/20], Step [170/3540], recon_error: 0.4239, perplexity: 6.9467
# Epoch[7/20], Step [180/3540], recon_error: 0.8872, perplexity: 10.7775
# Epoch[7/20], Step [190/3540], recon_error: 0.8064, perplexity: 13.0965
# Epoch[7/20], Step [200/3540], recon_error: 0.7856, perplexity: 9.1731
# Epoch[7/20], Step [210/3540], recon_error: 1.1383, perplexity: 12.7606
# Epoch[7/20], Step [220/3540], recon_error: 0.8392, perplexity: 10.7077
# Epoch[7/20], Step [230/3540], recon_error: 0.8835, perplexity: 12.0731
# Epoch[7/20], Step [240/3540], recon_error: 0.8789, perplexity: 10.5564
# Epoch[7/20], Step [250/3540], recon_error: 1.1544, perplexity: 16.2952
# Epoch[7/20], Step [260/3540], recon_error: 1.1183, perplexity: 13.6938
# Epoch[7/20], Step [270/3540], recon_error: 0.9927, perplexity: 13.8503
# Epoch[7/20], Step [280/3540], recon_error: 0.9357, perplexity: 13.8728
# Epoch[7/20], Step [290/3540], recon_error: 1.2895, perplexity: 13.4355
# Epoch[7/20], Step [300/3540], recon_error: 0.7380, perplexity: 12.2091
# Epoch[7/20], Step [310/3540], recon_error: 0.7559, perplexity: 9.4875
# Epoch[7/20], Step [320/3540], recon_error: 0.7654, perplexity: 14.6616
# Epoch[7/20], Step [330/3540], recon_error: 1.5520, perplexity: 20.1189
# Epoch[7/20], Step [340/3540], recon_error: 0.7316, perplexity: 10.9102
# Epoch[7/20], Step [350/3540], recon_error: 1.1280, perplexity: 11.7945
# Epoch[7/20], Step [360/3540], recon_error: 0.7096, perplexity: 9.0966
# Epoch[7/20], Step [370/3540], recon_error: 0.5748, perplexity: 10.5246
# Epoch[7/20], Step [380/3540], recon_error: 0.7496, perplexity: 9.0086
# Epoch[7/20], Step [390/3540], recon_error: 0.5465, perplexity: 8.4907
# Epoch[7/20], Step [400/3540], recon_error: 0.5223, perplexity: 10.5207
# Epoch[7/20], Step [410/3540], recon_error: 0.6535, perplexity: 11.1303
# Epoch[7/20], Step [420/3540], recon_error: 0.6533, perplexity: 10.6140
# Epoch[7/20], Step [430/3540], recon_error: 0.8763, perplexity: 12.5805
# Epoch[7/20], Step [440/3540], recon_error: 0.6866, perplexity: 11.0841
# Epoch[8/20], Step [10/3540], recon_error: 0.8974, perplexity: 14.2418
# Epoch[8/20], Step [20/3540], recon_error: 1.1510, perplexity: 12.3758
# Epoch[8/20], Step [30/3540], recon_error: 1.2925, perplexity: 15.5904
# Epoch[8/20], Step [40/3540], recon_error: 1.1379, perplexity: 15.1529
# Epoch[8/20], Step [50/3540], recon_error: 1.0108, perplexity: 11.1667
# Epoch[8/20], Step [60/3540], recon_error: 1.0629, perplexity: 14.9834
# Epoch[8/20], Step [70/3540], recon_error: 0.8480, perplexity: 12.4875
# Epoch[8/20], Step [80/3540], recon_error: 1.0205, perplexity: 10.7755
# Epoch[8/20], Step [90/3540], recon_error: 0.8020, perplexity: 9.7078
# Epoch[8/20], Step [100/3540], recon_error: 1.1182, perplexity: 12.2949
# Epoch[8/20], Step [110/3540], recon_error: 0.9659, perplexity: 13.2070
# Epoch[8/20], Step [120/3540], recon_error: 0.9341, perplexity: 16.3647
# Epoch[8/20], Step [130/3540], recon_error: 0.8662, perplexity: 9.9984
# Epoch[8/20], Step [140/3540], recon_error: 1.1516, perplexity: 12.0942
# Epoch[8/20], Step [150/3540], recon_error: 0.9197, perplexity: 13.6346
# Epoch[8/20], Step [160/3540], recon_error: 1.1838, perplexity: 15.3729
# Epoch[8/20], Step [170/3540], recon_error: 0.9312, perplexity: 12.5987
# Epoch[8/20], Step [180/3540], recon_error: 1.2475, perplexity: 12.5997
# Epoch[8/20], Step [190/3540], recon_error: 1.1296, perplexity: 16.8219
# Epoch[8/20], Step [200/3540], recon_error: 0.8618, perplexity: 10.4564
# Epoch[8/20], Step [210/3540], recon_error: 1.2363, perplexity: 17.2265
# Epoch[8/20], Step [220/3540], recon_error: 0.5546, perplexity: 6.7188
# Epoch[8/20], Step [230/3540], recon_error: 0.8861, perplexity: 11.0070
# Epoch[8/20], Step [240/3540], recon_error: 0.7164, perplexity: 7.5138
# Epoch[8/20], Step [250/3540], recon_error: 1.0177, perplexity: 10.4633
# Epoch[8/20], Step [260/3540], recon_error: 0.7735, perplexity: 10.2106
# Epoch[8/20], Step [270/3540], recon_error: 0.6816, perplexity: 9.4738
# Epoch[8/20], Step [280/3540], recon_error: 0.6543, perplexity: 9.8880
# Epoch[8/20], Step [290/3540], recon_error: 0.5999, perplexity: 9.0590
# Epoch[8/20], Step [300/3540], recon_error: 0.5329, perplexity: 7.2003
# Epoch[8/20], Step [310/3540], recon_error: 0.5655, perplexity: 8.5659
# Epoch[8/20], Step [320/3540], recon_error: 0.8652, perplexity: 12.8697
# Epoch[8/20], Step [330/3540], recon_error: 1.0027, perplexity: 11.4334
# Epoch[8/20], Step [340/3540], recon_error: 0.7886, perplexity: 13.1047
# Epoch[8/20], Step [350/3540], recon_error: 1.1840, perplexity: 14.0534
# Epoch[8/20], Step [360/3540], recon_error: 0.5648, perplexity: 8.8469
# Epoch[8/20], Step [370/3540], recon_error: 0.8303, perplexity: 10.7601
# Epoch[8/20], Step [380/3540], recon_error: 1.1704, perplexity: 16.5115
# Epoch[8/20], Step [390/3540], recon_error: 0.8954, perplexity: 13.4005
# Epoch[8/20], Step [400/3540], recon_error: 1.8139, perplexity: 19.6580
# Epoch[8/20], Step [410/3540], recon_error: 0.6163, perplexity: 8.5959
# Epoch[8/20], Step [420/3540], recon_error: 1.4297, perplexity: 12.0224
# Epoch[8/20], Step [430/3540], recon_error: 1.1970, perplexity: 12.0988
# Epoch[8/20], Step [440/3540], recon_error: 0.8360, perplexity: 10.8922
# Epoch[9/20], Step [10/3540], recon_error: 1.3080, perplexity: 18.2184
# Epoch[9/20], Step [20/3540], recon_error: 0.6662, perplexity: 7.9751
# Epoch[9/20], Step [30/3540], recon_error: 0.8193, perplexity: 8.2363
# Epoch[9/20], Step [40/3540], recon_error: 0.9717, perplexity: 11.5882
# Epoch[9/20], Step [50/3540], recon_error: 1.0422, perplexity: 10.4335
# Epoch[9/20], Step [60/3540], recon_error: 0.7909, perplexity: 15.2585
# Epoch[9/20], Step [70/3540], recon_error: 0.7517, perplexity: 12.6264
# Epoch[9/20], Step [80/3540], recon_error: 0.7097, perplexity: 10.9817
# Epoch[9/20], Step [90/3540], recon_error: 0.9367, perplexity: 14.1036
# Epoch[9/20], Step [100/3540], recon_error: 0.7146, perplexity: 11.6753
# Epoch[9/20], Step [110/3540], recon_error: 0.8595, perplexity: 12.7711
# Epoch[9/20], Step [120/3540], recon_error: 0.8894, perplexity: 14.9724
# Epoch[9/20], Step [130/3540], recon_error: 1.3428, perplexity: 11.7659
# Epoch[9/20], Step [140/3540], recon_error: 0.6098, perplexity: 7.9172
# Epoch[9/20], Step [150/3540], recon_error: 0.7762, perplexity: 12.6724
# Epoch[9/20], Step [160/3540], recon_error: 1.1468, perplexity: 14.0507
# Epoch[9/20], Step [170/3540], recon_error: 1.0141, perplexity: 12.5248
# Epoch[9/20], Step [180/3540], recon_error: 1.1151, perplexity: 15.6124
# Epoch[9/20], Step [190/3540], recon_error: 0.9451, perplexity: 10.3061
# Epoch[9/20], Step [200/3540], recon_error: 0.7657, perplexity: 11.9397
# Epoch[9/20], Step [210/3540], recon_error: 0.5524, perplexity: 7.8271
# Epoch[9/20], Step [220/3540], recon_error: 1.9131, perplexity: 21.3313
# Epoch[9/20], Step [230/3540], recon_error: 0.9411, perplexity: 14.0826
# Epoch[9/20], Step [240/3540], recon_error: 0.7755, perplexity: 9.7581
# Epoch[9/20], Step [250/3540], recon_error: 0.8552, perplexity: 11.6109
# Epoch[9/20], Step [260/3540], recon_error: 0.8845, perplexity: 10.8344
# Epoch[9/20], Step [270/3540], recon_error: 1.0939, perplexity: 10.1395
# Epoch[9/20], Step [280/3540], recon_error: 1.1791, perplexity: 14.0272
# Epoch[9/20], Step [290/3540], recon_error: 0.5207, perplexity: 9.6651
# Epoch[9/20], Step [300/3540], recon_error: 0.7592, perplexity: 11.3562
# Epoch[9/20], Step [310/3540], recon_error: 1.0052, perplexity: 13.6651
# Epoch[9/20], Step [320/3540], recon_error: 1.0588, perplexity: 14.0775
# Epoch[9/20], Step [330/3540], recon_error: 0.9942, perplexity: 17.2638
# Epoch[9/20], Step [340/3540], recon_error: 1.1298, perplexity: 20.6468
# Epoch[9/20], Step [350/3540], recon_error: 0.8021, perplexity: 10.9011
# Epoch[9/20], Step [360/3540], recon_error: 0.8874, perplexity: 12.9619
# Epoch[9/20], Step [370/3540], recon_error: 0.8132, perplexity: 10.3449
# Epoch[9/20], Step [380/3540], recon_error: 1.1936, perplexity: 14.6265
# Epoch[9/20], Step [390/3540], recon_error: 0.8620, perplexity: 11.7177
# Epoch[9/20], Step [400/3540], recon_error: 0.7482, perplexity: 8.3419
# Epoch[9/20], Step [410/3540], recon_error: 0.6496, perplexity: 8.3225
# Epoch[9/20], Step [420/3540], recon_error: 0.6856, perplexity: 10.0328
# Epoch[9/20], Step [430/3540], recon_error: 0.5944, perplexity: 8.8371
# Epoch[9/20], Step [440/3540], recon_error: 1.1948, perplexity: 18.0527
# Epoch[10/20], Step [10/3540], recon_error: 1.3503, perplexity: 12.4251
# Epoch[10/20], Step [20/3540], recon_error: 1.2590, perplexity: 11.4281
# Epoch[10/20], Step [30/3540], recon_error: 0.9498, perplexity: 10.4994
# Epoch[10/20], Step [40/3540], recon_error: 1.6797, perplexity: 12.3005
# Epoch[10/20], Step [50/3540], recon_error: 1.3408, perplexity: 12.4881
# Epoch[10/20], Step [60/3540], recon_error: 1.2529, perplexity: 11.1134
# Epoch[10/20], Step [70/3540], recon_error: 0.7232, perplexity: 7.0511
# Epoch[10/20], Step [80/3540], recon_error: 1.4069, perplexity: 12.9702
# Epoch[10/20], Step [90/3540], recon_error: 0.8260, perplexity: 9.3299
# Epoch[10/20], Step [100/3540], recon_error: 0.8311, perplexity: 10.5878
# Epoch[10/20], Step [110/3540], recon_error: 0.8188, perplexity: 8.3336
# Epoch[10/20], Step [120/3540], recon_error: 1.3974, perplexity: 13.8634
# Epoch[10/20], Step [130/3540], recon_error: 0.9334, perplexity: 12.5178
# Epoch[10/20], Step [140/3540], recon_error: 1.4295, perplexity: 14.4746
# Epoch[10/20], Step [150/3540], recon_error: 1.0671, perplexity: 13.0186
# Epoch[10/20], Step [160/3540], recon_error: 1.0342, perplexity: 9.6696
# Epoch[10/20], Step [170/3540], recon_error: 1.4863, perplexity: 15.3680
# Epoch[10/20], Step [180/3540], recon_error: 1.5473, perplexity: 12.4483
# Epoch[10/20], Step [190/3540], recon_error: 0.8226, perplexity: 11.6063
# Epoch[10/20], Step [200/3540], recon_error: 0.9432, perplexity: 9.8879
# Epoch[10/20], Step [210/3540], recon_error: 1.4582, perplexity: 13.0456
# Epoch[10/20], Step [220/3540], recon_error: 1.0199, perplexity: 9.7452
# Epoch[10/20], Step [230/3540], recon_error: 1.0168, perplexity: 12.0169
# Epoch[10/20], Step [240/3540], recon_error: 1.6134, perplexity: 14.7481
# Epoch[10/20], Step [250/3540], recon_error: 1.1589, perplexity: 10.0154
# Epoch[10/20], Step [260/3540], recon_error: 0.7564, perplexity: 8.9344
# Epoch[10/20], Step [270/3540], recon_error: 1.8928, perplexity: 15.4205
# Epoch[10/20], Step [280/3540], recon_error: 0.6516, perplexity: 8.5316
# Epoch[10/20], Step [290/3540], recon_error: 1.2510, perplexity: 12.8591
# Epoch[10/20], Step [300/3540], recon_error: 1.5599, perplexity: 11.7263
# Epoch[10/20], Step [310/3540], recon_error: 1.2887, perplexity: 11.1873
# Epoch[10/20], Step [320/3540], recon_error: 1.1202, perplexity: 11.5922
# Epoch[10/20], Step [330/3540], recon_error: 0.7559, perplexity: 8.0742
# Epoch[10/20], Step [340/3540], recon_error: 1.2431, perplexity: 13.6666
# Epoch[10/20], Step [350/3540], recon_error: 1.1562, perplexity: 10.2673
# Epoch[10/20], Step [360/3540], recon_error: 1.3949, perplexity: 12.5205
# Epoch[10/20], Step [370/3540], recon_error: 1.0884, perplexity: 13.5121
# Epoch[10/20], Step [380/3540], recon_error: 0.7195, perplexity: 7.5425
# Epoch[10/20], Step [390/3540], recon_error: 0.9136, perplexity: 7.5256
# Epoch[10/20], Step [400/3540], recon_error: 0.8962, perplexity: 8.9027
# Epoch[10/20], Step [410/3540], recon_error: 1.0283, perplexity: 9.9926
# Epoch[10/20], Step [420/3540], recon_error: 1.0446, perplexity: 10.7441
# Epoch[10/20], Step [430/3540], recon_error: 1.5831, perplexity: 16.1707
# Epoch[10/20], Step [440/3540], recon_error: 0.7972, perplexity: 9.2912
# Epoch[11/20], Step [10/3540], recon_error: 0.8615, perplexity: 8.7835
# Epoch[11/20], Step [20/3540], recon_error: 0.7034, perplexity: 10.4008
# Epoch[11/20], Step [30/3540], recon_error: 0.8954, perplexity: 14.9462
# Epoch[11/20], Step [40/3540], recon_error: 0.8994, perplexity: 12.8056
# Epoch[11/20], Step [50/3540], recon_error: 0.7006, perplexity: 11.2751
# Epoch[11/20], Step [60/3540], recon_error: 0.9002, perplexity: 13.5781
# Epoch[11/20], Step [70/3540], recon_error: 0.9917, perplexity: 11.8768
# Epoch[11/20], Step [80/3540], recon_error: 0.6973, perplexity: 10.8297
# Epoch[11/20], Step [90/3540], recon_error: 0.8705, perplexity: 9.6638
# Epoch[11/20], Step [100/3540], recon_error: 1.3418, perplexity: 13.9507
# Epoch[11/20], Step [110/3540], recon_error: 0.9358, perplexity: 13.5186
# Epoch[11/20], Step [120/3540], recon_error: 1.0921, perplexity: 14.0902
# Epoch[11/20], Step [130/3540], recon_error: 1.0229, perplexity: 9.8647
# Epoch[11/20], Step [140/3540], recon_error: 0.9567, perplexity: 13.8165
# Epoch[11/20], Step [150/3540], recon_error: 0.6975, perplexity: 10.3552
# Epoch[11/20], Step [160/3540], recon_error: 1.0952, perplexity: 13.2024
# Epoch[11/20], Step [170/3540], recon_error: 1.1551, perplexity: 13.5725
# Epoch[11/20], Step [180/3540], recon_error: 0.7964, perplexity: 11.4254
# Epoch[11/20], Step [190/3540], recon_error: 0.8638, perplexity: 12.0404
# Epoch[11/20], Step [200/3540], recon_error: 1.0206, perplexity: 12.0509
# Epoch[11/20], Step [210/3540], recon_error: 0.7345, perplexity: 10.6326
# Epoch[11/20], Step [220/3540], recon_error: 1.3955, perplexity: 13.0916
# Epoch[11/20], Step [230/3540], recon_error: 0.9329, perplexity: 13.4104
# Epoch[11/20], Step [240/3540], recon_error: 0.7027, perplexity: 9.6168
# Epoch[11/20], Step [250/3540], recon_error: 1.1659, perplexity: 16.0687
# Epoch[11/20], Step [260/3540], recon_error: 0.6863, perplexity: 11.6311
# Epoch[11/20], Step [270/3540], recon_error: 0.6736, perplexity: 13.3055
# Epoch[11/20], Step [280/3540], recon_error: 0.9800, perplexity: 10.1224
# Epoch[11/20], Step [290/3540], recon_error: 1.0559, perplexity: 10.9141
# Epoch[11/20], Step [300/3540], recon_error: 1.1079, perplexity: 12.3769
# Epoch[11/20], Step [310/3540], recon_error: 0.8771, perplexity: 14.4799
# Epoch[11/20], Step [320/3540], recon_error: 0.9392, perplexity: 14.7164
# Epoch[11/20], Step [330/3540], recon_error: 1.0605, perplexity: 13.2506
# Epoch[11/20], Step [340/3540], recon_error: 1.4940, perplexity: 18.9684
# Epoch[11/20], Step [350/3540], recon_error: 1.2733, perplexity: 13.2377
# Epoch[11/20], Step [360/3540], recon_error: 0.9582, perplexity: 13.5644
# Epoch[11/20], Step [370/3540], recon_error: 0.9003, perplexity: 11.6169
# Epoch[11/20], Step [380/3540], recon_error: 0.8123, perplexity: 11.0294
# Epoch[11/20], Step [390/3540], recon_error: 0.9691, perplexity: 11.5931
# Epoch[11/20], Step [400/3540], recon_error: 1.5248, perplexity: 14.1846
# Epoch[11/20], Step [410/3540], recon_error: 0.9007, perplexity: 8.9125
# Epoch[11/20], Step [420/3540], recon_error: 0.6881, perplexity: 9.9874
# Epoch[11/20], Step [430/3540], recon_error: 0.9426, perplexity: 12.2405
# Epoch[11/20], Step [440/3540], recon_error: 0.7319, perplexity: 10.9638
# Epoch[12/20], Step [10/3540], recon_error: 0.6736, perplexity: 7.5959
# Epoch[12/20], Step [20/3540], recon_error: 0.9258, perplexity: 11.2197
# Epoch[12/20], Step [30/3540], recon_error: 1.0198, perplexity: 12.4569
# Epoch[12/20], Step [40/3540], recon_error: 0.8013, perplexity: 8.8027
# Epoch[12/20], Step [50/3540], recon_error: 1.0442, perplexity: 11.4187
# Epoch[12/20], Step [60/3540], recon_error: 1.0264, perplexity: 16.5402
# Epoch[12/20], Step [70/3540], recon_error: 0.8295, perplexity: 9.6666
# Epoch[12/20], Step [80/3540], recon_error: 0.7527, perplexity: 9.8653
# Epoch[12/20], Step [90/3540], recon_error: 1.2795, perplexity: 18.7513
# Epoch[12/20], Step [100/3540], recon_error: 0.6670, perplexity: 11.7654
# Epoch[12/20], Step [110/3540], recon_error: 0.6016, perplexity: 11.2208
# Epoch[12/20], Step [120/3540], recon_error: 0.8984, perplexity: 12.7127
# Epoch[12/20], Step [130/3540], recon_error: 0.5498, perplexity: 8.4687
# Epoch[12/20], Step [140/3540], recon_error: 0.7230, perplexity: 12.0027
# Epoch[12/20], Step [150/3540], recon_error: 0.8674, perplexity: 9.4998
# Epoch[12/20], Step [160/3540], recon_error: 1.0182, perplexity: 15.4028
# Epoch[12/20], Step [170/3540], recon_error: 1.2607, perplexity: 17.3976
# Epoch[12/20], Step [180/3540], recon_error: 1.0104, perplexity: 13.0540
# Epoch[12/20], Step [190/3540], recon_error: 0.8628, perplexity: 11.0469
# Epoch[12/20], Step [200/3540], recon_error: 0.9275, perplexity: 11.3563
# Epoch[12/20], Step [210/3540], recon_error: 0.9387, perplexity: 15.3162
# Epoch[12/20], Step [220/3540], recon_error: 1.2723, perplexity: 16.3972
# Epoch[12/20], Step [230/3540], recon_error: 0.8116, perplexity: 12.2526
# Epoch[12/20], Step [240/3540], recon_error: 1.1816, perplexity: 12.3288
# Epoch[12/20], Step [250/3540], recon_error: 1.0051, perplexity: 13.9157
# Epoch[12/20], Step [260/3540], recon_error: 0.7947, perplexity: 12.3341
# Epoch[12/20], Step [270/3540], recon_error: 0.7915, perplexity: 11.6276
# Epoch[12/20], Step [280/3540], recon_error: 0.7705, perplexity: 12.6048
# Epoch[12/20], Step [290/3540], recon_error: 0.5891, perplexity: 10.2622
# Epoch[12/20], Step [300/3540], recon_error: 1.1699, perplexity: 15.1157
# Epoch[12/20], Step [310/3540], recon_error: 1.0169, perplexity: 13.4882
# Epoch[12/20], Step [320/3540], recon_error: 1.0376, perplexity: 13.5506
# Epoch[12/20], Step [330/3540], recon_error: 0.8632, perplexity: 12.0481
# Epoch[12/20], Step [340/3540], recon_error: 0.5704, perplexity: 9.3967
# Epoch[12/20], Step [350/3540], recon_error: 0.8796, perplexity: 13.4435
# Epoch[12/20], Step [360/3540], recon_error: 0.7273, perplexity: 10.0666
# Epoch[12/20], Step [370/3540], recon_error: 0.8251, perplexity: 10.0846
# Epoch[12/20], Step [380/3540], recon_error: 0.6668, perplexity: 11.0604
# Epoch[12/20], Step [390/3540], recon_error: 0.7620, perplexity: 10.1494
# Epoch[12/20], Step [400/3540], recon_error: 0.7317, perplexity: 10.5443
# Epoch[12/20], Step [410/3540], recon_error: 0.7692, perplexity: 10.5775
# Epoch[12/20], Step [420/3540], recon_error: 1.0242, perplexity: 14.7746
# Epoch[12/20], Step [430/3540], recon_error: 0.8723, perplexity: 11.7664
# Epoch[12/20], Step [440/3540], recon_error: 0.7906, perplexity: 9.8692
# Epoch[13/20], Step [10/3540], recon_error: 0.7993, perplexity: 9.9665
# Epoch[13/20], Step [20/3540], recon_error: 1.1214, perplexity: 10.0689
# Epoch[13/20], Step [30/3540], recon_error: 0.9745, perplexity: 10.0293
# Epoch[13/20], Step [40/3540], recon_error: 1.3739, perplexity: 14.6391
# Epoch[13/20], Step [50/3540], recon_error: 1.2688, perplexity: 12.0193
# Epoch[13/20], Step [60/3540], recon_error: 1.1380, perplexity: 11.2989
# Epoch[13/20], Step [70/3540], recon_error: 0.9623, perplexity: 11.8162
# Epoch[13/20], Step [80/3540], recon_error: 1.0359, perplexity: 12.8884
# Epoch[13/20], Step [90/3540], recon_error: 0.7967, perplexity: 11.2564
# Epoch[13/20], Step [100/3540], recon_error: 1.0162, perplexity: 12.2622
# Epoch[13/20], Step [110/3540], recon_error: 0.8652, perplexity: 10.8588
# Epoch[13/20], Step [120/3540], recon_error: 1.3182, perplexity: 15.0417
# Epoch[13/20], Step [130/3540], recon_error: 1.0629, perplexity: 10.4305
# Epoch[13/20], Step [140/3540], recon_error: 0.7153, perplexity: 8.2215
# Epoch[13/20], Step [150/3540], recon_error: 1.6618, perplexity: 15.5553
# Epoch[13/20], Step [160/3540], recon_error: 1.4155, perplexity: 14.9403
# Epoch[13/20], Step [170/3540], recon_error: 1.2087, perplexity: 15.8714
# Epoch[13/20], Step [180/3540], recon_error: 1.7916, perplexity: 15.7470
# Epoch[13/20], Step [190/3540], recon_error: 1.1138, perplexity: 14.9841
# Epoch[13/20], Step [200/3540], recon_error: 0.9410, perplexity: 10.7634
# Epoch[13/20], Step [210/3540], recon_error: 0.8993, perplexity: 10.4589
# Epoch[13/20], Step [220/3540], recon_error: 1.0914, perplexity: 14.1236
# Epoch[13/20], Step [230/3540], recon_error: 1.0937, perplexity: 14.7797
# Epoch[13/20], Step [240/3540], recon_error: 1.3231, perplexity: 14.3115
# Epoch[13/20], Step [250/3540], recon_error: 1.1899, perplexity: 10.8682
# Epoch[13/20], Step [260/3540], recon_error: 1.0840, perplexity: 14.3977
# Epoch[13/20], Step [270/3540], recon_error: 0.7815, perplexity: 8.0658
# Epoch[13/20], Step [280/3540], recon_error: 1.8424, perplexity: 15.4305
# Epoch[13/20], Step [290/3540], recon_error: 1.2206, perplexity: 12.9999
# Epoch[13/20], Step [300/3540], recon_error: 0.6977, perplexity: 10.0514
# Epoch[13/20], Step [310/3540], recon_error: 0.7729, perplexity: 10.4871
# Epoch[13/20], Step [320/3540], recon_error: 1.2614, perplexity: 12.7076
# Epoch[13/20], Step [330/3540], recon_error: 1.0411, perplexity: 10.2211
# Epoch[13/20], Step [340/3540], recon_error: 1.5371, perplexity: 16.0062
# Epoch[13/20], Step [350/3540], recon_error: 0.7597, perplexity: 8.3593
# Epoch[13/20], Step [360/3540], recon_error: 0.8909, perplexity: 10.3819
# Epoch[13/20], Step [370/3540], recon_error: 1.0555, perplexity: 9.5735
# Epoch[13/20], Step [380/3540], recon_error: 1.1300, perplexity: 12.0483
# Epoch[13/20], Step [390/3540], recon_error: 0.9152, perplexity: 8.8614
# Epoch[13/20], Step [400/3540], recon_error: 0.9575, perplexity: 10.7688
# Epoch[13/20], Step [410/3540], recon_error: 1.2647, perplexity: 12.0685
# Epoch[13/20], Step [420/3540], recon_error: 0.8958, perplexity: 11.5316
# Epoch[13/20], Step [430/3540], recon_error: 0.9195, perplexity: 10.6922
# Epoch[13/20], Step [440/3540], recon_error: 1.0227, perplexity: 11.9222
# Epoch[14/20], Step [10/3540], recon_error: 0.6123, perplexity: 13.2702
# Epoch[14/20], Step [20/3540], recon_error: 0.7659, perplexity: 13.3858
# Epoch[14/20], Step [30/3540], recon_error: 1.0180, perplexity: 12.3706
# Epoch[14/20], Step [40/3540], recon_error: 1.0362, perplexity: 11.9451
# Epoch[14/20], Step [50/3540], recon_error: 0.9980, perplexity: 11.5127
# Epoch[14/20], Step [60/3540], recon_error: 1.1504, perplexity: 14.0392
# Epoch[14/20], Step [70/3540], recon_error: 0.6534, perplexity: 9.1480
# Epoch[14/20], Step [80/3540], recon_error: 0.9682, perplexity: 10.6785
# Epoch[14/20], Step [90/3540], recon_error: 0.7813, perplexity: 11.4661
# Epoch[14/20], Step [100/3540], recon_error: 0.9419, perplexity: 14.5174
# Epoch[14/20], Step [110/3540], recon_error: 0.8986, perplexity: 15.1516
# Epoch[14/20], Step [120/3540], recon_error: 0.6776, perplexity: 10.7455
# Epoch[14/20], Step [130/3540], recon_error: 0.8660, perplexity: 8.1670
# Epoch[14/20], Step [140/3540], recon_error: 1.1020, perplexity: 17.1495
# Epoch[14/20], Step [150/3540], recon_error: 0.5873, perplexity: 9.4061
# Epoch[14/20], Step [160/3540], recon_error: 1.2201, perplexity: 12.6459
# Epoch[14/20], Step [170/3540], recon_error: 1.3076, perplexity: 17.3955
# Epoch[14/20], Step [180/3540], recon_error: 1.0702, perplexity: 13.6005
# Epoch[14/20], Step [190/3540], recon_error: 1.2282, perplexity: 15.9183
# Epoch[14/20], Step [200/3540], recon_error: 1.0139, perplexity: 12.7227
# Epoch[14/20], Step [210/3540], recon_error: 1.4331, perplexity: 14.2234
# Epoch[14/20], Step [220/3540], recon_error: 0.9814, perplexity: 10.8603
# Epoch[14/20], Step [230/3540], recon_error: 0.8983, perplexity: 11.8770
# Epoch[14/20], Step [240/3540], recon_error: 1.0064, perplexity: 13.6014
# Epoch[14/20], Step [250/3540], recon_error: 0.9544, perplexity: 12.5289
# Epoch[14/20], Step [260/3540], recon_error: 0.7481, perplexity: 9.0321
# Epoch[14/20], Step [270/3540], recon_error: 0.8957, perplexity: 14.8747
# Epoch[14/20], Step [280/3540], recon_error: 0.7275, perplexity: 9.0152
# Epoch[14/20], Step [290/3540], recon_error: 0.6894, perplexity: 12.8567
# Epoch[14/20], Step [300/3540], recon_error: 0.8869, perplexity: 13.5516
# Epoch[14/20], Step [310/3540], recon_error: 1.0797, perplexity: 12.6051
# Epoch[14/20], Step [320/3540], recon_error: 1.0815, perplexity: 15.6368
# Epoch[14/20], Step [330/3540], recon_error: 1.1008, perplexity: 14.9302
# Epoch[14/20], Step [340/3540], recon_error: 0.9832, perplexity: 12.7864
# Epoch[14/20], Step [350/3540], recon_error: 0.7386, perplexity: 9.9231
# Epoch[14/20], Step [360/3540], recon_error: 1.3248, perplexity: 17.6766
# Epoch[14/20], Step [370/3540], recon_error: 1.0025, perplexity: 12.9771
# Epoch[14/20], Step [380/3540], recon_error: 0.7578, perplexity: 12.0136
# Epoch[14/20], Step [390/3540], recon_error: 1.3155, perplexity: 16.5754
# Epoch[14/20], Step [400/3540], recon_error: 0.9218, perplexity: 9.6557
# Epoch[14/20], Step [410/3540], recon_error: 0.7892, perplexity: 12.0653
# Epoch[14/20], Step [420/3540], recon_error: 1.0360, perplexity: 14.8830
# Epoch[14/20], Step [430/3540], recon_error: 0.7552, perplexity: 10.7264
# Epoch[14/20], Step [440/3540], recon_error: 0.6022, perplexity: 7.9503
# Epoch[15/20], Step [10/3540], recon_error: 0.5551, perplexity: 10.0584
# Epoch[15/20], Step [20/3540], recon_error: 0.8724, perplexity: 9.9652
# Epoch[15/20], Step [30/3540], recon_error: 0.8275, perplexity: 10.1371
# Epoch[15/20], Step [40/3540], recon_error: 1.1176, perplexity: 16.0631
# Epoch[15/20], Step [50/3540], recon_error: 0.6214, perplexity: 9.0892
# Epoch[15/20], Step [60/3540], recon_error: 0.6339, perplexity: 8.3888
# Epoch[15/20], Step [70/3540], recon_error: 0.8317, perplexity: 11.3500
# Epoch[15/20], Step [80/3540], recon_error: 1.9914, perplexity: 22.1358
# Epoch[15/20], Step [90/3540], recon_error: 0.5148, perplexity: 9.1544
# Epoch[15/20], Step [100/3540], recon_error: 0.9268, perplexity: 12.4453
# Epoch[15/20], Step [110/3540], recon_error: 0.6904, perplexity: 9.1575
# Epoch[15/20], Step [120/3540], recon_error: 0.8486, perplexity: 12.3860
# Epoch[15/20], Step [130/3540], recon_error: 0.5495, perplexity: 8.8037
# Epoch[15/20], Step [140/3540], recon_error: 0.6681, perplexity: 8.9012
# Epoch[15/20], Step [150/3540], recon_error: 1.2392, perplexity: 15.8301
# Epoch[15/20], Step [160/3540], recon_error: 1.2829, perplexity: 18.0226
# Epoch[15/20], Step [170/3540], recon_error: 0.8085, perplexity: 9.0953
# Epoch[15/20], Step [180/3540], recon_error: 0.9720, perplexity: 13.3225
# Epoch[15/20], Step [190/3540], recon_error: 0.7122, perplexity: 8.4917
# Epoch[15/20], Step [200/3540], recon_error: 0.9294, perplexity: 11.6961
# Epoch[15/20], Step [210/3540], recon_error: 0.8649, perplexity: 13.5765
# Epoch[15/20], Step [220/3540], recon_error: 1.0879, perplexity: 9.8917
# Epoch[15/20], Step [230/3540], recon_error: 1.3531, perplexity: 17.4068
# Epoch[15/20], Step [240/3540], recon_error: 1.1256, perplexity: 12.3844
# Epoch[15/20], Step [250/3540], recon_error: 0.9699, perplexity: 10.7977
# Epoch[15/20], Step [260/3540], recon_error: 1.2872, perplexity: 10.2359
# Epoch[15/20], Step [270/3540], recon_error: 0.5889, perplexity: 7.7188
# Epoch[15/20], Step [280/3540], recon_error: 1.1993, perplexity: 16.4749
# Epoch[15/20], Step [290/3540], recon_error: 0.8842, perplexity: 13.3748
# Epoch[15/20], Step [300/3540], recon_error: 0.8859, perplexity: 11.2259
# Epoch[15/20], Step [310/3540], recon_error: 0.7146, perplexity: 10.2296
# Epoch[15/20], Step [320/3540], recon_error: 0.7115, perplexity: 10.4602
# Epoch[15/20], Step [330/3540], recon_error: 1.0997, perplexity: 15.2653
# Epoch[15/20], Step [340/3540], recon_error: 1.0132, perplexity: 11.7804
# Epoch[15/20], Step [350/3540], recon_error: 0.9448, perplexity: 10.7498
# Epoch[15/20], Step [360/3540], recon_error: 0.6098, perplexity: 10.2569
# Epoch[15/20], Step [370/3540], recon_error: 1.1024, perplexity: 13.7919
# Epoch[15/20], Step [380/3540], recon_error: 1.4078, perplexity: 14.2669
# Epoch[15/20], Step [390/3540], recon_error: 0.9733, perplexity: 14.1647
# Epoch[15/20], Step [400/3540], recon_error: 0.9262, perplexity: 12.3379
# Epoch[15/20], Step [410/3540], recon_error: 1.1609, perplexity: 13.5728
# Epoch[15/20], Step [420/3540], recon_error: 0.9444, perplexity: 12.8564
# Epoch[15/20], Step [430/3540], recon_error: 1.3700, perplexity: 18.4542
# Epoch[15/20], Step [440/3540], recon_error: 0.8760, perplexity: 9.0006
# Epoch[16/20], Step [10/3540], recon_error: 0.7486, perplexity: 9.3809
# Epoch[16/20], Step [20/3540], recon_error: 1.0428, perplexity: 13.0334
# Epoch[16/20], Step [30/3540], recon_error: 1.0637, perplexity: 14.0816
# Epoch[16/20], Step [40/3540], recon_error: 1.1198, perplexity: 10.1470
# Epoch[16/20], Step [50/3540], recon_error: 1.0818, perplexity: 10.9303
# Epoch[16/20], Step [60/3540], recon_error: 0.8827, perplexity: 7.7010
# Epoch[16/20], Step [70/3540], recon_error: 1.1492, perplexity: 12.8258
# Epoch[16/20], Step [80/3540], recon_error: 1.0312, perplexity: 10.4429
# Epoch[16/20], Step [90/3540], recon_error: 0.8801, perplexity: 9.6670
# Epoch[16/20], Step [100/3540], recon_error: 1.3109, perplexity: 13.2582
# Epoch[16/20], Step [110/3540], recon_error: 1.0347, perplexity: 9.6129
# Epoch[16/20], Step [120/3540], recon_error: 1.2733, perplexity: 12.9744
# Epoch[16/20], Step [130/3540], recon_error: 0.6254, perplexity: 8.3521
# Epoch[16/20], Step [140/3540], recon_error: 1.0097, perplexity: 11.0743
# Epoch[16/20], Step [150/3540], recon_error: 0.9692, perplexity: 10.3105
# Epoch[16/20], Step [160/3540], recon_error: 1.0726, perplexity: 14.6929
# Epoch[16/20], Step [170/3540], recon_error: 1.5100, perplexity: 17.1496
# Epoch[16/20], Step [180/3540], recon_error: 0.7850, perplexity: 10.1435
# Epoch[16/20], Step [190/3540], recon_error: 1.4265, perplexity: 13.8284
# Epoch[16/20], Step [200/3540], recon_error: 1.0202, perplexity: 11.2999
# Epoch[16/20], Step [210/3540], recon_error: 0.6774, perplexity: 8.4491
# Epoch[16/20], Step [220/3540], recon_error: 1.3414, perplexity: 11.3585
# Epoch[16/20], Step [230/3540], recon_error: 1.1687, perplexity: 10.4471
# Epoch[16/20], Step [240/3540], recon_error: 0.8119, perplexity: 10.2505
# Epoch[16/20], Step [250/3540], recon_error: 0.6689, perplexity: 7.8493
# Epoch[16/20], Step [260/3540], recon_error: 1.0195, perplexity: 12.9314
# Epoch[16/20], Step [270/3540], recon_error: 1.2964, perplexity: 10.8523
# Epoch[16/20], Step [280/3540], recon_error: 1.2046, perplexity: 14.6340
# Epoch[16/20], Step [290/3540], recon_error: 1.5461, perplexity: 13.9240
# Epoch[16/20], Step [300/3540], recon_error: 1.7680, perplexity: 11.9032
# Epoch[16/20], Step [310/3540], recon_error: 1.0990, perplexity: 8.1406
# Epoch[16/20], Step [320/3540], recon_error: 1.3117, perplexity: 11.0888
# Epoch[16/20], Step [330/3540], recon_error: 0.8173, perplexity: 10.0103
# Epoch[16/20], Step [340/3540], recon_error: 0.7413, perplexity: 9.4278
# Epoch[16/20], Step [350/3540], recon_error: 1.5823, perplexity: 11.7681
# Epoch[16/20], Step [360/3540], recon_error: 0.8403, perplexity: 10.5558
# Epoch[16/20], Step [370/3540], recon_error: 1.3506, perplexity: 11.7367
# Epoch[16/20], Step [380/3540], recon_error: 1.0626, perplexity: 7.9368
# Epoch[16/20], Step [390/3540], recon_error: 2.4652, perplexity: 23.3024
# Epoch[16/20], Step [400/3540], recon_error: 1.0049, perplexity: 10.3895
# Epoch[16/20], Step [410/3540], recon_error: 0.6989, perplexity: 7.5238
# Epoch[16/20], Step [420/3540], recon_error: 0.8503, perplexity: 13.6545
# Epoch[16/20], Step [430/3540], recon_error: 1.4853, perplexity: 14.1501
# Epoch[16/20], Step [440/3540], recon_error: 0.9802, perplexity: 10.0671
# Epoch[17/20], Step [10/3540], recon_error: 0.8019, perplexity: 13.0500
# Epoch[17/20], Step [20/3540], recon_error: 0.8395, perplexity: 9.2950
# Epoch[17/20], Step [30/3540], recon_error: 1.2855, perplexity: 17.4890
# Epoch[17/20], Step [40/3540], recon_error: 0.9497, perplexity: 14.8400
# Epoch[17/20], Step [50/3540], recon_error: 0.5603, perplexity: 10.6158
# Epoch[17/20], Step [60/3540], recon_error: 1.0850, perplexity: 15.5925
# Epoch[17/20], Step [70/3540], recon_error: 0.8346, perplexity: 12.9494
# Epoch[17/20], Step [80/3540], recon_error: 1.0120, perplexity: 17.0236
# Epoch[17/20], Step [90/3540], recon_error: 1.1343, perplexity: 16.5894
# Epoch[17/20], Step [100/3540], recon_error: 0.8333, perplexity: 10.2751
# Epoch[17/20], Step [110/3540], recon_error: 1.0872, perplexity: 17.2543
# Epoch[17/20], Step [120/3540], recon_error: 0.6362, perplexity: 9.0739
# Epoch[17/20], Step [130/3540], recon_error: 0.9202, perplexity: 11.4775
# Epoch[17/20], Step [140/3540], recon_error: 1.3847, perplexity: 14.5267
# Epoch[17/20], Step [150/3540], recon_error: 0.9859, perplexity: 13.6943
# Epoch[17/20], Step [160/3540], recon_error: 1.2395, perplexity: 13.3429
# Epoch[17/20], Step [170/3540], recon_error: 1.1705, perplexity: 14.8664
# Epoch[17/20], Step [180/3540], recon_error: 0.7315, perplexity: 13.8507
# Epoch[17/20], Step [190/3540], recon_error: 1.2643, perplexity: 13.3050
# Epoch[17/20], Step [200/3540], recon_error: 1.2080, perplexity: 14.3957
# Epoch[17/20], Step [210/3540], recon_error: 1.1809, perplexity: 12.4448
# Epoch[17/20], Step [220/3540], recon_error: 0.8727, perplexity: 13.3523
# Epoch[17/20], Step [230/3540], recon_error: 0.8578, perplexity: 9.4859
# Epoch[17/20], Step [240/3540], recon_error: 1.1391, perplexity: 12.2552
# Epoch[17/20], Step [250/3540], recon_error: 0.8011, perplexity: 12.0602
# Epoch[17/20], Step [260/3540], recon_error: 0.8287, perplexity: 12.9741
# Epoch[17/20], Step [270/3540], recon_error: 1.0173, perplexity: 17.6172
# Epoch[17/20], Step [280/3540], recon_error: 1.0616, perplexity: 10.7705
# Epoch[17/20], Step [290/3540], recon_error: 1.0646, perplexity: 10.5717
# Epoch[17/20], Step [300/3540], recon_error: 0.7114, perplexity: 9.6846
# Epoch[17/20], Step [310/3540], recon_error: 0.8489, perplexity: 10.7765
# Epoch[17/20], Step [320/3540], recon_error: 0.7975, perplexity: 12.1976
# Epoch[17/20], Step [330/3540], recon_error: 0.6894, perplexity: 9.5204
# Epoch[17/20], Step [340/3540], recon_error: 1.0733, perplexity: 15.3076
# Epoch[17/20], Step [350/3540], recon_error: 1.2112, perplexity: 16.4356
# Epoch[17/20], Step [360/3540], recon_error: 0.6779, perplexity: 8.8410
# Epoch[17/20], Step [370/3540], recon_error: 0.6224, perplexity: 9.7813
# Epoch[17/20], Step [380/3540], recon_error: 0.5681, perplexity: 11.2035
# Epoch[17/20], Step [390/3540], recon_error: 0.9193, perplexity: 13.0723
# Epoch[17/20], Step [400/3540], recon_error: 0.5781, perplexity: 8.9882
# Epoch[17/20], Step [410/3540], recon_error: 0.8306, perplexity: 11.7216
# Epoch[17/20], Step [420/3540], recon_error: 1.5230, perplexity: 15.0190
# Epoch[17/20], Step [430/3540], recon_error: 0.8123, perplexity: 10.5867
# Epoch[17/20], Step [440/3540], recon_error: 0.8471, perplexity: 10.8239
# Epoch[18/20], Step [10/3540], recon_error: 0.5858, perplexity: 8.6405
# Epoch[18/20], Step [20/3540], recon_error: 1.0074, perplexity: 13.9992
# Epoch[18/20], Step [30/3540], recon_error: 1.1139, perplexity: 11.2187
# Epoch[18/20], Step [40/3540], recon_error: 0.7415, perplexity: 10.4075
# Epoch[18/20], Step [50/3540], recon_error: 0.8741, perplexity: 12.9806
# Epoch[18/20], Step [60/3540], recon_error: 0.8375, perplexity: 11.6213
# Epoch[18/20], Step [70/3540], recon_error: 1.2595, perplexity: 10.0539
# Epoch[18/20], Step [80/3540], recon_error: 0.5600, perplexity: 7.6925
# Epoch[18/20], Step [90/3540], recon_error: 0.9057, perplexity: 10.3108
# Epoch[18/20], Step [100/3540], recon_error: 0.8090, perplexity: 9.9519
# Epoch[18/20], Step [110/3540], recon_error: 1.1692, perplexity: 12.2426
# Epoch[18/20], Step [120/3540], recon_error: 1.1387, perplexity: 14.0373
# Epoch[18/20], Step [130/3540], recon_error: 1.0611, perplexity: 13.7425
# Epoch[18/20], Step [140/3540], recon_error: 1.1294, perplexity: 13.2479
# Epoch[18/20], Step [150/3540], recon_error: 1.8004, perplexity: 12.3403
# Epoch[18/20], Step [160/3540], recon_error: 1.2786, perplexity: 14.4822
# Epoch[18/20], Step [170/3540], recon_error: 1.1053, perplexity: 11.3660
# Epoch[18/20], Step [180/3540], recon_error: 1.1396, perplexity: 13.5438
# Epoch[18/20], Step [190/3540], recon_error: 1.2936, perplexity: 15.7875
# Epoch[18/20], Step [200/3540], recon_error: 1.0342, perplexity: 12.6348
# Epoch[18/20], Step [210/3540], recon_error: 1.8666, perplexity: 17.5562
# Epoch[18/20], Step [220/3540], recon_error: 1.2868, perplexity: 14.4182
# Epoch[18/20], Step [230/3540], recon_error: 1.0604, perplexity: 11.3500
# Epoch[18/20], Step [240/3540], recon_error: 0.7049, perplexity: 9.5961
# Epoch[18/20], Step [250/3540], recon_error: 1.4333, perplexity: 17.1880
# Epoch[18/20], Step [260/3540], recon_error: 0.9337, perplexity: 10.4568
# Epoch[18/20], Step [270/3540], recon_error: 1.2996, perplexity: 12.8998
# Epoch[18/20], Step [280/3540], recon_error: 1.8357, perplexity: 20.2214
# Epoch[18/20], Step [290/3540], recon_error: 1.1689, perplexity: 10.1460
# Epoch[18/20], Step [300/3540], recon_error: 1.3089, perplexity: 16.7392
# Epoch[18/20], Step [310/3540], recon_error: 0.9317, perplexity: 9.6543
# Epoch[18/20], Step [320/3540], recon_error: 1.3420, perplexity: 11.8136
# Epoch[18/20], Step [330/3540], recon_error: 0.8597, perplexity: 10.2323
# Epoch[18/20], Step [340/3540], recon_error: 1.0739, perplexity: 10.9880
# Epoch[18/20], Step [350/3540], recon_error: 1.1395, perplexity: 14.3840
# Epoch[18/20], Step [360/3540], recon_error: 1.1321, perplexity: 14.1855
# Epoch[18/20], Step [370/3540], recon_error: 0.8273, perplexity: 9.9493
# Epoch[18/20], Step [380/3540], recon_error: 0.9801, perplexity: 11.7463
# Epoch[18/20], Step [390/3540], recon_error: 1.0120, perplexity: 14.2870
# Epoch[18/20], Step [400/3540], recon_error: 1.1114, perplexity: 11.3977
# Epoch[18/20], Step [410/3540], recon_error: 0.9627, perplexity: 10.6054
# Epoch[18/20], Step [420/3540], recon_error: 0.8025, perplexity: 11.7347
# Epoch[18/20], Step [430/3540], recon_error: 0.6745, perplexity: 9.3529
# Epoch[18/20], Step [440/3540], recon_error: 1.0155, perplexity: 11.0715
# Epoch[19/20], Step [10/3540], recon_error: 0.7399, perplexity: 13.6408
# Epoch[19/20], Step [20/3540], recon_error: 0.6103, perplexity: 10.8577
# Epoch[19/20], Step [30/3540], recon_error: 1.0263, perplexity: 15.6751
# Epoch[19/20], Step [40/3540], recon_error: 1.0679, perplexity: 14.4820
# Epoch[19/20], Step [50/3540], recon_error: 0.5814, perplexity: 9.6510
# Epoch[19/20], Step [60/3540], recon_error: 0.9735, perplexity: 12.4029
# Epoch[19/20], Step [70/3540], recon_error: 0.9050, perplexity: 11.3704
# Epoch[19/20], Step [80/3540], recon_error: 0.7876, perplexity: 13.7109
# Epoch[19/20], Step [90/3540], recon_error: 1.7824, perplexity: 19.8813
# Epoch[19/20], Step [100/3540], recon_error: 0.6657, perplexity: 8.2909
# Epoch[19/20], Step [110/3540], recon_error: 1.4260, perplexity: 12.7221
# Epoch[19/20], Step [120/3540], recon_error: 0.8478, perplexity: 11.9879
# Epoch[19/20], Step [130/3540], recon_error: 1.0177, perplexity: 15.1022
# Epoch[19/20], Step [140/3540], recon_error: 1.0124, perplexity: 13.5566
# Epoch[19/20], Step [150/3540], recon_error: 0.9542, perplexity: 14.2162
# Epoch[19/20], Step [160/3540], recon_error: 1.4231, perplexity: 14.6357
# Epoch[19/20], Step [170/3540], recon_error: 1.0047, perplexity: 14.1192
# Epoch[19/20], Step [180/3540], recon_error: 1.2353, perplexity: 14.7072
# Epoch[19/20], Step [190/3540], recon_error: 0.5070, perplexity: 9.4578
# Epoch[19/20], Step [200/3540], recon_error: 0.6727, perplexity: 11.3644
# Epoch[19/20], Step [210/3540], recon_error: 1.0034, perplexity: 15.8768
# Epoch[19/20], Step [220/3540], recon_error: 1.2657, perplexity: 18.2888
# Epoch[19/20], Step [230/3540], recon_error: 0.7105, perplexity: 10.0833
# Epoch[19/20], Step [240/3540], recon_error: 1.1862, perplexity: 10.1305
# Epoch[19/20], Step [250/3540], recon_error: 1.2306, perplexity: 13.1193
# Epoch[19/20], Step [260/3540], recon_error: 0.9241, perplexity: 11.9445
# Epoch[19/20], Step [270/3540], recon_error: 0.5338, perplexity: 7.8062
# Epoch[19/20], Step [280/3540], recon_error: 1.0244, perplexity: 10.2747
# Epoch[19/20], Step [290/3540], recon_error: 1.0741, perplexity: 12.7084
# Epoch[19/20], Step [300/3540], recon_error: 0.7081, perplexity: 8.7471
# Epoch[19/20], Step [310/3540], recon_error: 0.9339, perplexity: 12.5307
# Epoch[19/20], Step [320/3540], recon_error: 0.9246, perplexity: 11.6458
# Epoch[19/20], Step [330/3540], recon_error: 1.4034, perplexity: 14.8372
# Epoch[19/20], Step [340/3540], recon_error: 0.8669, perplexity: 11.4192
# Epoch[19/20], Step [350/3540], recon_error: 0.9376, perplexity: 13.8206
# Epoch[19/20], Step [360/3540], recon_error: 1.1085, perplexity: 11.7179
# Epoch[19/20], Step [370/3540], recon_error: 1.1486, perplexity: 13.0549
# Epoch[19/20], Step [380/3540], recon_error: 0.4763, perplexity: 6.9839
# Epoch[19/20], Step [390/3540], recon_error: 0.7429, perplexity: 10.4450
# Epoch[19/20], Step [400/3540], recon_error: 1.2733, perplexity: 12.5883
# Epoch[19/20], Step [410/3540], recon_error: 0.7725, perplexity: 9.9562
# Epoch[19/20], Step [420/3540], recon_error: 0.7763, perplexity: 9.1481
# Epoch[19/20], Step [430/3540], recon_error: 1.3011, perplexity: 14.4202
# Epoch[19/20], Step [440/3540], recon_error: 1.0533, perplexity: 11.5241
# Epoch[20/20], Step [10/3540], recon_error: 0.6435, perplexity: 9.2738
# Epoch[20/20], Step [20/3540], recon_error: 0.8722, perplexity: 11.6453
# Epoch[20/20], Step [30/3540], recon_error: 1.3189, perplexity: 14.7747
# Epoch[20/20], Step [40/3540], recon_error: 0.8347, perplexity: 15.6278
# Epoch[20/20], Step [50/3540], recon_error: 1.3474, perplexity: 14.2522
# Epoch[20/20], Step [60/3540], recon_error: 0.6658, perplexity: 11.4062
# Epoch[20/20], Step [70/3540], recon_error: 1.1926, perplexity: 16.6715
# Epoch[20/20], Step [80/3540], recon_error: 0.8313, perplexity: 14.3060
# Epoch[20/20], Step [90/3540], recon_error: 1.1142, perplexity: 12.2979
# Epoch[20/20], Step [100/3540], recon_error: 1.0855, perplexity: 11.7661
# Epoch[20/20], Step [110/3540], recon_error: 1.0088, perplexity: 10.8585
# Epoch[20/20], Step [120/3540], recon_error: 0.5964, perplexity: 8.2770
# Epoch[20/20], Step [130/3540], recon_error: 0.6263, perplexity: 9.1915
# Epoch[20/20], Step [140/3540], recon_error: 0.7158, perplexity: 11.1411
# Epoch[20/20], Step [150/3540], recon_error: 0.6971, perplexity: 10.1560
# Epoch[20/20], Step [160/3540], recon_error: 0.8228, perplexity: 10.3366
# Epoch[20/20], Step [170/3540], recon_error: 1.0637, perplexity: 15.0941
# Epoch[20/20], Step [180/3540], recon_error: 0.8198, perplexity: 14.4323
# Epoch[20/20], Step [190/3540], recon_error: 1.0371, perplexity: 14.1285
# Epoch[20/20], Step [200/3540], recon_error: 0.6553, perplexity: 9.3244
# Epoch[20/20], Step [210/3540], recon_error: 1.8103, perplexity: 17.7185
# Epoch[20/20], Step [220/3540], recon_error: 0.6747, perplexity: 9.7235
# Epoch[20/20], Step [230/3540], recon_error: 0.5879, perplexity: 9.0547
# Epoch[20/20], Step [240/3540], recon_error: 0.9902, perplexity: 10.3603
# Epoch[20/20], Step [250/3540], recon_error: 1.1058, perplexity: 14.8069
# Epoch[20/20], Step [260/3540], recon_error: 1.0104, perplexity: 12.3500
# Epoch[20/20], Step [270/3540], recon_error: 1.2400, perplexity: 14.2123
# Epoch[20/20], Step [280/3540], recon_error: 1.0300, perplexity: 12.8510
# Epoch[20/20], Step [290/3540], recon_error: 0.6691, perplexity: 11.3790
# Epoch[20/20], Step [300/3540], recon_error: 1.0457, perplexity: 13.1933
# Epoch[20/20], Step [310/3540], recon_error: 0.7310, perplexity: 13.0537
# Epoch[20/20], Step [320/3540], recon_error: 0.6255, perplexity: 8.7387
# Epoch[20/20], Step [330/3540], recon_error: 0.6653, perplexity: 12.7987
# Epoch[20/20], Step [340/3540], recon_error: 0.7741, perplexity: 11.1810
# Epoch[20/20], Step [350/3540], recon_error: 0.7241, perplexity: 9.1858
# Epoch[20/20], Step [360/3540], recon_error: 0.9070, perplexity: 14.5897
# Epoch[20/20], Step [370/3540], recon_error: 0.8554, perplexity: 9.4271
# Epoch[20/20], Step [380/3540], recon_error: 1.0519, perplexity: 18.1279
# Epoch[20/20], Step [390/3540], recon_error: 1.0818, perplexity: 8.7262
# Epoch[20/20], Step [400/3540], recon_error: 0.7361, perplexity: 9.8441
# Epoch[20/20], Step [410/3540], recon_error: 0.6859, perplexity: 9.6887
# Epoch[20/20], Step [420/3540], recon_error: 0.7215, perplexity: 11.6418
# Epoch[20/20], Step [430/3540], recon_error: 0.9964, perplexity: 13.5159
# Epoch[20/20], Step [440/3540], recon_error: 1.5421, perplexity: 15.6406

# %%
epoch_loss
# Out:
# 12273.898899048567

# %%
plt.plot(val_res_recon_error)

# %%
plt.plot(train_res_perplexity)

# %%
val_res_recon_error_smooth = savgol_filter(val_res_recon_error, 15, 4)
val_res_perplexity_smooth = savgol_filter(train_res_perplexity, 15, 4)

# %%
f = plt.figure(figsize=(16,8))
ax = f.add_subplot(1,2,1)
ax.plot(val_res_recon_error_smooth)
#ax.set_yscale('log')
ax.set_title('Smoothed NMSE.')
ax = f.add_subplot(1,2,2)
ax.plot(val_res_perplexity_smooth)
ax.set_title('Smoothed Average codebook usage (perplexity).')
# Out:
# Text(0.5, 1.0, 'Smoothed Average codebook usage (perplexity).')

# %%
len(val_res_recon_error)
# Out:
# 20

# %%
optim.Adam?
